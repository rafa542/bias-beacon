# %% [markdown]
# # Data Loading, Cleaning and Wrangling

# %%
#Need to run this to have the right path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Installing the right stuff
# !pip install -q sentencepiece
# !pip install -q transformers
# !pip install -q evaluate
# !pip install -q rouge_score
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import evaluate
from pprint import pprint

# %%
#Building path and opening the files to create the dataframe
data_path = "/content/drive/MyDrive/266 NLP - Final Project/all_the_news_SUBSET_Kaggle/"

df1 = pd.read_csv(data_path + "articles1.csv").iloc[:, 1:]
df2 = pd.read_csv(data_path + "articles2.csv").iloc[:, 1:]
df3 = pd.read_csv(data_path + "articles3.csv").iloc[:, 1:]

data = pd.concat([df1, df2, df3])

# %%
### Data Characteristics
## Each id is unique to each row/headline with no duplicate articles/rows
## 142,570 total headline and articles

## 1.85% of the data doesn't have dates but I feel like it's ok to get rid of them since it's such a small sample
data[data["date"].isnull()].shape[0]/data.shape[0]
data = data[~data["date"].isnull()]

## Out of all the articles, 99.7% of them are from 2015-2017 so it might not be helpful to keep the older articles before 2015 since there are so few
data.value_counts("year").sort_index(ascending=False)
data = data[data["year"]>2014]

data = data.reset_index()

#Added word count column
data['article_wd_ct'] = data['content'].str.split().str.len() ## word count of each article

## Only subsetting for article that have at least 100 words- could do more analysis into including ones between 70-100 but the ones I've seen in that range aren't fully populated articles or poorly extracted articles
data = data[data["article_wd_ct"]>=100]

## Further subsetting the data for articles below 500 words for ease of running the models
data = data[data["article_wd_ct"]<=500]

# %% [markdown]
# Data Cleaning for Headlines.
#
# A manual process done publication by publication

# %%
#Atlantic
data = data.drop(data.loc[(data.publication=="Atlantic") & (data.title.str.contains("Atlantic"))].index)

#Breitbart
data.loc[((data.publication=="Breitbart") & (data.title.str.contains("- Breitbart"))), "title"] = data[(data["publication"] == "Breitbart") & (data["title"].str.contains("- Breitbart"))].title.str[:-12]
data = data.drop(data.loc[(data.publication=="Breitbart") & ( (data.title.str.contains("Breitbart")) | (data.title.str.contains("BREITBART")) )].index)

#Business Insider
data = data.drop(data.loc[(data.publication=="Business Insider") & ((data.title.str.contains("Business Insider")) | (data.title.str.contains("BUSINESS INSIDER")) )].index)

#BuzzFeed
data = data.drop(data.loc[(data.publication=="Buzzfeed News") & ((data.title.str.contains("BuzzFeed")) | (data.title.str.contains("BUZZFEED")) )].index)

#CNN
data = data.drop(data.loc[(data.publication=="CNN") & (data.title.str.contains("CNN"))].index)

#Fox News
#Fix all the aforementioned appendings. Data frame should be equal size to above, 53089, can use that to validate.
data.loc[((data.publication=="Fox News") & (data.title.str.contains("Fox News Poll:"))), "title"] = data[(data["publication"] == "Fox News") & (data["title"].str.contains("Fox News Poll:"))].title.str[15:]
data.loc[((data.publication=="Fox News") & (data.title.str.contains("Fox News Electoral Scorecard:"))), "title"] = data[(data["publication"] == "Fox News") & (data["title"].str.contains("Fox News Electoral Scorecard:"))].title.str[30:]
data.loc[((data.publication=="Fox News") & (data.title.str.contains("Fox News projects:"))), "title"] = data[(data["publication"] == "Fox News") & (data["title"].str.contains("Fox News projects:"))].title.str[19:]
data = data.drop(data.loc[(data.publication=="Fox News") & ((data.title.str.contains("Fox")) | (data.title.str.contains("FOX")) )].index)

#Guardian
data = data.drop(data.loc[(data.publication=="Guardian") & (data.title.str.contains("Guardian"))].index)

#National Review
data = data.drop(data.loc[(data.publication=="National Review") & ( (data.title.str.contains("NR ")) | (data.title.str.contains("NR:")) | (data.title.str.contains("NRI")) | (data.title.str.contains("NRO")) )].index)

#New York Post
data = data.drop(data.loc[(data.publication=="New York Post") & (data.title.str.contains("New York Post"))].index)

#New York Times
data.loc[data.publication=="New York Times", "title"] = data[data['publication'] == "New York Times"].title.str[:-21]
data = data.drop(data.loc[(data.publication=="New York Times") & (data.title.str.contains("New York Times"))].index)

#NPR
data = data.drop(data.loc[(data.publication=="NPR") & (data.title.str.contains("NPR"))].index)

#Reuters
data = data.drop(data.loc[(data.publication=="Reuters") & (data.title.str.contains("Reuters"))].index)

#Talking Points Memo
data = data.drop(data.loc[(data.publication=="Talking Points Memo") & (data.title.str.contains("TPM"))].index)

#Vox
data = data.drop(data.loc[(data.publication=="Vox") & (data.title.str.contains("Vox"))].index)

#Washington Post
data = data.drop(data.loc[(data.publication=="Washington Post") & (data.title.str.contains("Washington Post"))].index)

# %%
#Totals got iffy, but it's at 52959
data.reset_index()

data

#Do not uncomment unless you want to download
#data.to_excel("CLEANED compact.xlsx")
# Out:
#         index      id                                              title  \
# 5           5   17288  Sick With a Cold, Queen Elizabeth Misses New Y...
# 19         19   17303  Fecal Pollution Taints Water at Melbourne’s Be...
# 33         33   17323  Airline Pilot, Believed to Be Drunk, Is Pulled...
# 47         47   17338  It’s Time to Ignore Advice About Which Stocks ...
# 52         52   17344  Chinese City Official Shoots 2 Others and Kill...
# ...       ...     ...                                                ...
# 139478  42535  218042  Debbie Reynolds was a trouper all the way to t...
# 139487  42544  218051  An obscure E.U. regulation may have saved live...
# 139492  42549  218056  A woman ordered canaries to brighten her home....
# 139494  42551  218063  Trump praises Putin’s response to sanctions, c...
# 139495  42552  218064  Russia slams Obama administration and CNN for ...
#
#             publication                     author        date    year  month  \
# 5        New York Times                Sewell Chan  2017-01-02  2017.0    1.0
# 19       New York Times                 Brett Cole  2017-01-03  2017.0    1.0
# 33       New York Times                 Ian Austen  2017-01-03  2017.0    1.0
# 47       New York Times               Damon Darlin  2017-01-09  2017.0    1.0
# 52       New York Times  Chris Buckley and Adam Wu  2017-01-05  2017.0    1.0
# ...                 ...                        ...         ...     ...    ...
# 139478  Washington Post               Ann Hornaday  2016-12-29  2016.0   12.0
# 139487  Washington Post                Adam Taylor  2016-12-29  2016.0   12.0
# 139492  Washington Post                   Avi Selk  2016-12-29  2016.0   12.0
# 139494  Washington Post           Karoun Demirjian  2016-12-30  2016.0   12.0
# 139495  Washington Post                Adam Taylor  2016-12-30  2016.0   12.0
#
#                                                       url  \
# 5                                                     NaN
# 19                                                    NaN
# 33                                                    NaN
# 47                                                    NaN
# 52                                                    NaN
# ...                                                   ...
# 139478  https://web.archive.org/web/20161230000842/htt...
# 139487  https://web.archive.org/web/20161230000842/htt...
# 139492  https://web.archive.org/web/20161230000842/htt...
# 139494  https://web.archive.org/web/20161231004909/htt...
# 139495  https://web.archive.org/web/20161231004909/htt...
#
#                                                   content  article_wd_ct
# 5       LONDON  —   Queen Elizabeth II, who has been b...            159
# 19      SYDNEY, Australia  —   The annual beach pilgri...            292
# 33      OTTAWA  —   It was 7 a. m. and 99 passengers a...            410
# 47      It’s that time of year when financial advice s...            395
# 52      BEIJING  —   A city official in southwest Chin...            358
# ...                                                   ...            ...
# 139478               Y ou can almost hear Carrie Fishe...            367
# 139487       The truck attack on a Christmas market in...            387
# 139492       Somewhere between Texas and Alabama, some...            373
# 139494         Donald Trump on Friday expressed his ap...            314
# 139495       Maria Zakharova, a spokeswoman for the Ru...            426
#
# [52958 rows x 11 columns]

# %% [markdown]
# #T5 Headline Evaluation

# %%
#Import all necessary libraries here
from transformers import T5Tokenizer, TFT5ForConditionalGeneration

#Initializing model and tokenizer
t5model = TFT5ForConditionalGeneration.from_pretrained("t5-base")
t5tokenizer = T5Tokenizer.from_pretrained("t5-base")

#Rouge evaluator
rouge = evaluate.load('rouge')
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFT5ForConditionalGeneration.
#
# All the weights of TFT5ForConditionalGeneration were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFT5ForConditionalGeneration for predictions without further training.
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/t5/tokenization_t5.py:240: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
#data[data['publication'] == 'New York Times'].iloc[0:100]

# %%
for i in data.publication.unique():
  print(i)
  #print(data[data['publication'] == i].iloc[0:5, 2:4])
# Out:
# New York Times
# Breitbart
# CNN
# Business Insider
# Atlantic
# Fox News
# Talking Points Memo
# Buzzfeed News
# National Review
# New York Post
# Guardian
# NPR
# Reuters
# Vox
# Washington Post

# %%
#Current batch
publication = "Washington Post"

token_range = 5
number_of_beams_parameter = 3
no_repeat_ngram_size_parameter = 2

# %%
data[data['publication'] == publication].iloc[0:100]
# Out:
#         index      id                                              title  \
# 128409  31464  204040              Is a Trump-Putin Pact on the horizon?
# 128421  31476  204053  5 habits worth cultivating in 2017, according ...
# 128422  31477  204054     Looking back at New Year’s Eve in Times Square
# 128439  31494  204087  Ethics advocates warn Trump that he needs to d...
# 128451  31506  204099  Israeli police question PM over corruption all...
# ...       ...     ...                                                ...
# 129223  32278  205035  These photos show what the U.S.-Mexican border...
# 129235  32290  205050  This monster tornado just rolled through New O...
# 129252  32307  205073  Nor’easter to slam Northeast Thursday with thu...
# 129259  32314  205080  Turning ordinary into magical: Amateur photogr...
# 129261  32316  205085  White House says Conway has been ‘counseled’ a...
#
#             publication             author        date    year  month  \
# 128409  Washington Post    Colbert I. King  2016-12-31  2016.0   12.0
# 128421  Washington Post     Carrie Dennett  2016-12-29  2016.0   12.0
# 128422  Washington Post   Karly Domb Sadof  2016-12-30  2016.0   12.0
# 128439  Washington Post      Tom Hamburger  2017-01-02  2017.0    1.0
# 128451  Washington Post        Griff Witte  2017-01-02  2017.0    1.0
# ...                 ...                ...         ...     ...    ...
# 129223  Washington Post   Karly Domb Sadof  2017-02-06  2017.0    2.0
# 129235  Washington Post       Angela Fritz  2017-02-07  2017.0    2.0
# 129252  Washington Post      Jason Samenow  2017-02-08  2017.0    2.0
# 129259  Washington Post  Kenneth Dickerman  2017-02-08  2017.0    2.0
# 129261  Washington Post       Drew Harwell  2017-02-09  2017.0    2.0
#
#                                                       url  \
# 128409  https://web.archive.org/web/20170101001641/htt...
# 128421  https://web.archive.org/web/20170101001641/htt...
# 128422  https://web.archive.org/web/20170101001641/htt...
# 128439  https://web.archive.org/web/20170103000951/htt...
# 128451  https://web.archive.org/web/20170103000951/htt...
# ...                                                   ...
# 129223  https://web.archive.org/web/20170207002306/htt...
# 129235  https://web.archive.org/web/20170208002026/htt...
# 129252  https://web.archive.org/web/20170209002805/htt...
# 129259  https://web.archive.org/web/20170209002805/htt...
# 129261  https://web.archive.org/web/20170210001650/htt...
#
#                                                   content  article_wd_ct
# 128409  Could there be a   Pact in our future? Could P...            351
# 128421   Whether you make formal New Year’s resolution...            304
# 128422          1930. (Associated Press)  “Auld Lang S...            235
# 128439  A bipartisan group of ethics advocates lobbed ...            343
# 128451    JERUSALEM  —   Israeli police investigators ...            197
# ...                                                   ...            ...
# 129223          A house on the U. S.  border in the Ri...            469
# 129235           Severe thunderstorms barreled through...            162
# 129252       A powerful winter storm is predicted to h...            425
# 129259          (Swarat Ghosh)  More often than not, p...            420
# 129261   President Trump’s official counselor, Kellyan...            480
#
# [100 rows x 11 columns]

# %%
#Headlines of the current batch
headlines = []

#Generated summaries of the current batch
generated_summary = []

#Rouge scores of the current batch
rouge_scores = []

# %%
#T5 is trained on several tasks, not just summarization. So we prepend the input with this to let the model know we want to summarie
PROMPT = 'summarize: '

#The range of
for i in range(100):

  #Getting current row
  Current_Article = data[data['publication'] == publication].iloc[i]

  #Article Content
  ARTICLE_TO_SUMMARIZE = Current_Article.content

  #Headline as reference
  REFERENCE = Current_Article.title
  headlines.append(REFERENCE)

  #Need to prompt BERT since it's trained on several tasks
  T5ARTICLE_TO_SUMMARIZE = PROMPT + ARTICLE_TO_SUMMARIZE

  #Tokenizing the input, aka prepping to put it into BERT
  inputs = t5tokenizer(T5ARTICLE_TO_SUMMARIZE, max_length=1024, truncation=True, return_tensors="tf")

  #Generating summary
  summary_ids = t5model.generate(inputs["input_ids"],
                                 num_beams=number_of_beams_parameter,
                                 max_length=len(t5tokenizer(REFERENCE)['input_ids']) + token_range,
                                 min_length=len(t5tokenizer(REFERENCE)['input_ids']) - token_range,
                                 no_repeat_ngram_size=no_repeat_ngram_size_parameter
                                 )
  #Decoding
  candidate = t5tokenizer.batch_decode(summary_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False)
  generated_summary.append(candidate[0])

  predictions = candidate
  references = [REFERENCE]
  results = rouge.compute(predictions=predictions,
                          references=references)
  rouge_scores.append(results)

  print(str(i), " done")
# Out:
# 0  done
# 1  done
# 2  done
# 3  done
# 4  done
# 5  done
# 6  done
# 7  done
# 8  done
# 9  done
# 10  done
# 11  done
# 12  done
# 13  done
# 14  done
# 15  done
# 16  done
# 17  done
# 18  done
# 19  done
# 20  done
# 21  done
# 22  done
# 23  done
# 24  done
# 25  done
# 26  done
# 27  done
# 28  done
# 29  done
# 30  done
# 31  done
# 32  done
# 33  done
# 34  done
# 35  done
# 36  done
# 37  done
# 38  done
# 39  done
# 40  done
# 41  done
# 42  done
# 43  done
# 44  done
# 45  done
# 46  done
# 47  done
# 48  done
# 49  done
# 50  done
# 51  done
# 52  done
# 53  done
# 54  done
# 55  done
# 56  done
# 57  done
# 58  done
# 59  done
# 60  done
# 61  done
# 62  done
# 63  done
# 64  done
# 65  done
# 66  done
# 67  done
# 68  done
# 69  done
# 70  done
# 71  done
# 72  done
# 73  done
# 74  done
# 75  done
# 76  done
# 77  done
# 78  done
# 79  done
# 80  done
# 81  done
# 82  done
# 83  done
# 84  done
# 85  done
# 86  done
# 87  done
# 88  done
# 89  done
# 90  done
# 91  done
# 92  done
# 93  done
# 94  done
# 95  done
# 96  done
# 97  done
# 98  done
# 99  done

# %%
headlines
# Out:
# ['Is a Trump-Putin Pact on the horizon?',
#  '5 habits worth cultivating in 2017, according to a dietitian',
#  'Looking back at New Year’s Eve in Times Square',
#  'Ethics advocates warn Trump that he needs to do more to divest from family business',
#  'Israeli police question PM over corruption allegations',
#  'Seldom-seen photos show what America looked like in the 1940s…in color',
#  'Megyn Kelly leaving Fox News for NBC',
#  'Militant who denounced Islamic State faces murder, war crimes charges in Germany',
#  'A man got a middle seat on a 13-hour flight. Passengers recorded his ‘fit of rage,’ then arrest.',
#  'Mysterious radio burst came from a galaxy 2.5 billion light years away, astronomers discover',
#  'Berlin attacker had 14 aliases, was subject of repeated counterterror briefings',
#  'Obama administration begins final tranche of Guantanamo prisoner transfers',
#  'Why losing Megyn Kelly probably won’t even dent Fox News’s armor',
#  'How Donald Trump totally destroyed Chris Christie',
#  'Mexicans make it clear once again how they feel about paying for Trump’s ‘Great Wall’',
#  'A resurrected House rule lets Congress go open season on civil servants',
#  'One chart shows how Obama’s job performance compares with his predecessors',
#  'PM Update: Bitter temperatures and wind chills tonight. Cold and blustery for Sunday.',
#  'These casseroles will keep you warm when the weather turns rotten',
#  'Fresh takes on the classic Reuben are popping up at D.C.’s new sandwich shops',
#  'Trump advisers to begin tax talks with Speaker Ryan',
#  'Navy destroyer opens fire after ‘harassing’ behavior by Iranian patrol boats',
#  'Donald Trump says D.C.’s dress shops are sold out of inauguration gowns. Wrong!',
#  'U.S. posts second-warmest year on record, breadth of warmth ‘unparalleled’',
#  'Trump outlines plan to shift assets, give up management of his company',
#  'Here’s the difference between BuzzFeed’s publishing Russia docs and media publishing DNC hacks',
#  'Google’s parent has given up on one of its big, futuristic projects',
#  'These women hunters are redefining what it means to be ladylike',
#  'Placing Russia first among threats, Defense nominee warns of Kremlin attempts to ‘break’ NATO',
#  'Obama ending ‘wet-foot, dry-foot’ policy allowing Cubans reaching U.S. soil to stay and receive residency',
#  'Jeff Bezos is the anonymous buyer of the biggest house in Washington',
#  'William Peter Blatty, author of ‘The Exorcist,’ dies at 89',
#  'Comey should resign',
#  'Sunday afternoon’s Steelers-Chiefs game postponed until evening because of ice storm',
#  '‘I knew that a battlefield of suffering was in my eyes’: The many faces of Frida Kahlo',
#  'Chic desk accessories that will keep you stylish and motivated year-round',
#  'Trump national security spokeswoman Monica Crowley to forgo post amid plagiarism charges',
#  'Celebrities and N.Y.C. Mayor Bill de Blasio plan to protest Trump day before inauguration',
#  'Senators scrutinize Betsy DeVos, Trump’s pick for Education Secretary',
#  'Donald Trump waits in his tower — accessible yet isolated',
#  'Bill O’Reilly’s New Year’s resolution: No more ‘fanatical ideologues’ on ‘The Factor’',
#  'What Democrats must avoid in fighting back against Trump',
#  'Nigerian military ‘mistake’ kills at least 50 in attack on safe-haven town',
#  'Interior secretary nominee Zinke: National parks repair list should be part of Trump infrastructure plan',
#  'Britainâ€™s May promises clean break from Europe in Brexit speech',
#  'UC President Janet Napolitano hospitalized with cancer',
#  'U.S. scientists officially declare 2016 the hottest year on record. That makes three in a row.',
#  'Commutation of Chelsea Manning’s prison sentence sends a ‘very troubling message,’ Trump spokesman says',
#  'Former president George H.W. Bush hospitalized in Houston; Barbara Bush also under care',
#  'Looking back at some of the U.K.’s first teenagers, the Teddy Boys',
#  'From Italian hotel buried by avalanche: Desperate cries for help, then silence',
#  'Aide to Md. lawmaker fabricated article on fraudulent votes for Clinton',
#  'Donald Trump is sworn in as president, vows to end ‘American carnage’',
#  'Inauguration protesters vandalize, set fires, try to disrupt Trump’s oath, as police arrest more than 200',
#  'Trump’s inaugural speech was a sharp break with past — and his party',
#  'A most dreadful inaugural address',
#  'She’s 54, white, rural and a lifelong Republican. Why is she protesting Donald Trump?',
#  'Trump’s press secretary lashes out at press, calling crowd coverage ‘shameful and wrong’',
#  'My favorite signs at the Women’s March on Washington',
#  'What it’s like to have under three minutes to photograph president-elect Trump',
#  'Trump won’t release his tax returns because people don’t care, top adviser says',
#  'Trump freezes hiring of many federal workers',
#  'Sessions should recuse himself from investigations into the election',
#  'Trump seeks to revive Dakota Access, Keystone XL oil pipelines',
#  'Nikki Haley confirmed as new U.S. envoy to the United Nations',
#  'Arthur Brooks: The word dignity explains why Trump is president',
#  'The true, correct story of what happened at Donald Trump’s inauguration',
#  'How Trump became president, through one photographer’s lens',
#  'Trump signs directive to start border wall with Mexico, ramp up immigration enforcement',
#  '‘That’s not somebody’s Honda’: Owner of limo torched on Inauguration Day unsure if insurance will cover damages',
#  'Report: Coach K bars his players from locker room, forbids wearing Duke apparel',
#  'For this photographer, good food had nothing to do with eating',
#  'President Trump and Mexican president speak by phone amid crisis in relations',
#  'Trump says ‘torture’ works, but he’ll defer on decision over tactics to his defense secretary',
#  'March for Life: Pence speaks as thousands assemble at Washington Monument',
#  'This is what Elon Musk’s mysterious digging tweets are about',
#  'Is meat manly? How society pressures us to make gendered food choices.',
#  'Add glamour and warmth to your home with these metallic accents',
#  '‘We can’t become a dictatorship’: Protests erupt across the U.S. against Trump refugee ban',
#  'A Syrian woman flew to the U.S. to see her hospitalized mother. She was forced to turn around.',
#  '‘Donald Trump destroyed my life,’ says barred Iraqi who worked for U.S.',
#  'Spicer: Diplomats opposed to immigration ban should ‘either get with the program or they can go’',
#  'Obama rejects comparison between Trump’s immigration policy and his own, encourages protests',
#  '‘Thirty-six million hearts are breakingâ€™: Terrorist attack at Canadian mosque leaves a nation shaken',
#  'Trump is recklessly reversing Americansâ€™ progress in Iraq',
#  'A hoagie shop chain’s co-owner shakes Trump’s hand, and a Twitter outcry ensues',
#  'What life is like living with a ‘love doll’ in Japan',
#  'Jeff Sessions approved by Judiciary Committee after another bitter hearing',
#  'Israeli police begin forced removals of Amona settlers in the West Bank',
#  'Al-Qaeda says Trump has ignited ‘the flame of jihad’ with Yemen raid',
#  'Born in the front car of the Cyclone roller coaster, a photographer who truly adored Coney Island',
#  'State Dept. reverses visa revocations, allows barred travelers to enter U.S.',
#  'Dear Ruth Bader Ginsburg: If you need anything — blood, organs — take mine',
#  'Standing Rock Sioux want ‘no forcible removal’ of protesters from Dakota Access pipeline site',
#  'NCAA reportedly is on the verge of blackballing North Carolina for years over ‘bathroom bill’',
#  'These photos show what the U.S.-Mexican border looked like about 80 years ago',
#  'This monster tornado just rolled through New Orleans — major damage reported',
#  'Nor’easter to slam Northeast Thursday with thundersnow, whiteout conditions',
#  'Turning ordinary into magical: Amateur photographer presents new look at life in India',
#  'White House says Conway has been ‘counseled’ after touting Ivanka Trump’s products']

# %%
generated_summary
# Out:
# ['could there be a nonaggression agreement between the u.s. and russia? will the',
#  'cook more Creating and serving even the simplest of meals is a profound way of caring',
#  'since 1907, there have been only two Januaries — 1942 and 1943',
#  'the letter comes after Trump announced some changes in his business empire, with more expected before Inauguration Day',
#  'no charges have been filed against prime minister Benjamin Netanyahu .',
#  'the farm security administration (FSA) was created in 1937 from an earlier agency named the Resettlement Administration,',
#  'a person at NBC News confirmed that Kelly will leave the network for',
#  'german citizen Harry Sarfo appeared in front page articles and television broadcasts last year in which he offered',
#  "the man boarded a United Airlines flight on new year's day . he was seated between two of them, and didn't like their cross",
#  'dim dwarf galaxy 2. 5 billion light years from earth is sending out the mysterious blasts of radio waves . the bursts',
#  'anis amri was shot dead in a shootout with police in italy four days after the',
#  'the transfers represent the culmination of years of effort by the Obama administration to scale back operations at',
#  'despite making a personal appeal and proffering bags of money, the billionaire mogul couldn’t secure',
#  'the latest indignity came earlier this week when Christie',
#  "former president Vicente Fox vowed that his countrymen wouldn’t bankroll Trump’s 'racist monument",
#  'the house voted to reinstate a procedural rule that allows congress to retrench agency spending',
#  'unemployment has fallen under every president but Jimmy Carter and Ronald Reagan . the drop is partly because some',
#  'accumulation of snow has ended for most of us, leaving a nice coating across the District and some more substantial snow totals along',
#  'this list of 10 casseroles is from the Recipe Finder . put that lingering',
#  'Ilyse Fishman Lerner grew up on the Reuben, consuming more than her fair share at the',
#  'the private discussions will convene in Ryan’s office suite shortly after 7',
#  'the USS Mahan fired three warning shots with a machine gun at four Iranian boats after at least one',
#  'the 58th inauguration will take place on the 20th of january in washington d.c.',
#  'the nation’s average temperature was 54. 9 degrees, nearly 3 degrees above the average . only 2012 was warmer in historical records,',
#  "the move will target some of the businessman's most visible ethical vulnerabilities . a",
#  'the dossier is the work of a former western intelligence official . it relies on sources and, presumably, whispers and perhaps',
#  'the company has disbanded the team that had been developing the technology . many of the Titan',
#  'the latest global gender gap report from the world economic forum put Japan at 111th of',
#  "retired marine general argued for greater american support for european allies to counter what he said were Moscow's attempts to shatter the",
#  'the policy, put in place by the Clinton administration in 1996, altered the special immigration status of Cubans . a new flood of emigrants',
#  'the former textile museum sold for $23 million in cash on Oct. 21 . the property span',
#  'the cause was a form of multiple myeloma, said his wife, Julie Witbrodt',
#  "the justice department's inspector general is opening an investigation",
#  'the game between the Pittsburgh Steelers and the Kansas City Chiefs has been moved to 8:20 p. m. EDT',
#  'the exhibition is on display at the Harn Museum of Art until April 2 . it moves to the museum of Spanish Colonial art from May 6 to Oct',
#  "tobe Reed, the personality behind the design blog Because It's Awesome, recommends",
#  'the publisher of a 2012 book by Crowley said it will stop selling copies until she addresses allegations of',
#  'celebrities and mayor bill de Blasio will gather in new york to protest the future commander in chief on his home turf .',
#  'the hearing before the committee on health, education, labor and pensions (HELP) went forward Tuesday evening over the',
#  'one week after becoming Donald Trump stepped outside his namesake fortress here for',
#  'last summer, bill o\'Reilly said that he didn\'t "want to work this hard much longer" \'we are not going to use any fan',
#  'a new poll has little good news for incoming president .',
#  'the bombardment occurred in the town of Rann, near the cameroon border . more than 100 people were injured',
#  'rep. Ryan Zinke ( .) who is nominated to serve as the next interior secretary,',
#  "theresa may's speech eliminated any doubt her country would seek a clean break",
#  'former secretary of homeland security and governor of Arizona, she received her second cancer diagnosis in august',
#  'average surface temperatures in 2016, according to the National Oceanic and Atmospheric Administration, were 0. 07 degrees Fahrenheit warmer than',
#  'a spokesman for Trump said he was "troubled" by the commutation of the prison sentence of Chelsea Manning',
#  'the former president was taken to the hospital on Saturday for shortness of breath . doctors performed a procedure to',
#  'the "teenager" sweeping the uk in the 1950s was a cocktail of formal styling and vulgarity',
#  'a handful of survivors waited in what was left of the Hotel Rigopiano . one man was getting something from the',
#  'delegate David E. Vogt III said he terminated Cameron Harris "on the spot"',
#  'he promised to end "American carnage" in cities and restore jobs lost to shuttered factories .',
#  'six people intent on interrupting the presidential ceremony made it into the closest section of seats to Trump . the protesters were throwing rocks, bricks and chunks of concrete and taking',
#  'new president made clear that his will be a very different presidency . he spurned the',
#  'julian zelizer: in 1981 inauguration,',
#  "a woman on the bus to washington, d.c. says she has information about the women's voting group .",
#  "the president's press secretary left his first media briefing without taking questions, ignoring reporters who shouted questions at him",
#  'some were vulgar, others were angry. most were earnest . a',
#  'a 1941 image of Winston Churchill jumped out among the many prominent figures who sat for you',
#  'aide to president says he has no plans to release his tax returns . presidents are not required to',
#  "the move comes on the new president's first full working day",
#  'on tuesday the Senate Judiciary Committee will',
#  'the president signed executive orders to revive the controversial Dakota Access and Keystone XL oil pipelines',
#  's.c. governor nikki haley is confirmed to be the next u.s ambassador',
#  '"Cape Up" is a weekly podcast talking to key figures behind the news and',
#  'the crowd was magnificent and huge, bigger than any crowd had ever been before . "are',
#  'photographer Jabin Botsford followed the businessman and reality show star’s',
#  'president signs executive actions to begin ramping up immigration enforcement, including a new border wall with',
#  'the limo was set ablaze during an inauguration day protest in northwest washington . the driver of the $90, 000 car said he was told to',
#  'a source told ESPN that the penalties would last “until [the players] start living up to',
#  'photographer j_macpost was married to photographer and photographer John McDonnell .',
#  '"we had a very good call," he said in joint news conference with',
#  "'he will override,' he said in a joint news conference with British prime minister Theresa May at the white",
#  'thousands of abortion opponents gather near the washington monument . "we will not grow weary',
#  "the idea was first hatched by Musk in December, who tweeted, 'am going",
#  "men don't live as long as women do, according to a new study . advertising and social messaging tell",
#  'dabito incorporates metallics into his interior schemes to achieve a cool,',
#  'swarms of protesters amassed in front of the white house by 1 p.m. and by late afternoon the crowds proceeded to',
#  "'there is no good reason for me to not be able to enter. it’s a feeling of utter despair,' said",
#  'the sharef family flew from their home in Irbil to new york . they were told they could no longer travel to',
#  'white house press secretary has a stern message for State Department employees opposed to president Trump’s executive order banning immigration from seven countries',
#  'a federal judge in new york blocked deportations nationwide late Saturday of those detained on entry to the united',
#  "gunmen attacked a suburban mosque as worshipers were finishing their prayers . six people were killed and 19 others were wounded, five of them critically ' government officials",
#  'president obama has embarked on a policy that could lead to the loss',
#  'the founder of @TaylorGourmet met with the president for a connected to his executive order cutting regulations for small businesses . the meeting',
#  'in 2007, Ryan gosling played a character who has trouble making friends or even socializing with',
#  'the Senate Judiciary Committee on Wednesday voted 11 to 9 to advance the nomination',
#  'security forces removed several families from their homes and arrested a handful of activists that had turned out to support',
#  'that the raid came only days after Trump’s vow to eradicate Islamist terrorism in his inauguration speech',
#  'high school dropout and coney island native, was seen as a child prodigy in photography during his time . in 1950, at age',
#  'the department of homeland security complied with a judge’s orders and stopped enforcing President Trump’',
#  'sally kohn: i admire you very much and have some tokens of my esteem that you might enjoy',
#  'after months of protests, both tribal officials and residents in the town of Cannon Ball, N. D. have asked those opposed',
#  'HB2 mandates that transgender people use the bathroom corresponding with their birth gender in facilities and bans North Carolina municipalities from',
#  'the border was established in 1848 after the U. S. War ended with the Treaty of . aaron',
#  'storm chasers and residents filmed the large tornado across the populous new orleans',
#  'the storm, taking shape in the Wednesday night, will rapidly intensify as it roars up the coast on Thursday',
#  'photographer Swarat Ghosh is not a professional photographer but an avid amateur and student of the medium',
#  'legal experts said Conway had broken a key ethics law banning federal employees from using their public office to endorse products . white house']

# %%
rouge_scores
# Out:
# [{'rouge1': 0.18181818181818182,
#   'rouge2': 0.0,
#   'rougeL': 0.18181818181818182,
#   'rougeLsum': 0.18181818181818182},
#  {'rouge1': 0.07692307692307693,
#   'rouge2': 0.0,
#   'rougeL': 0.07692307692307693,
#   'rougeLsum': 0.07692307692307693},
#  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0},
#  {'rouge1': 0
#   'rougeLsum': 0.13333333333333333},
#  {'rouge1': 0.125, 'rouge2': 0.0, 'rougeL': 0.0625, 'rougeLsum': 0.0625},
#  {'rouge1': 0.08333333333333334,
#   'rouge2': 0.0,
#   'rougeL': 0.08333333333333334,
#   'rougeLsum': 0.08333333333333334},
#  {'rouge1': 0.3703703703703704,
#   'rouge2': 0.23999999999999996,
#   'rougeL': 0.2962962962962963,
#   'rougeLsum': 0.2962962962962963},
#  {'rouge1': 0.12765957446808512,
#   'rouge2': 0.0,
#   'rougeL': 0.0851063829787234,
#   'rougeLsum': 0.0851063829787234},
#  {'rouge1': 0.14285714285714288,
#   'rouge2': 0.0,
#   'rougeL': 0.07142857142857144,
#   'rougeLsum': 0.07142857142857144},
#  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0},
#  {'rouge1': 0.17647058823529413,
#   'rouge2': 0.0,
#   'rougeL': 0.11764705882352941,
#   'rougeLsum': 0.11764705882352941},
#  {'rouge1': 0.23529411764705882,
#   'rouge2': 0.125,
#   'rougeL': 0.23529411764705882,
#   'rougeLsum': 0.23529411764705882},
#  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0},
#  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0},
#  {'rouge1': 0.303030303030303,
#   'rouge2': 0.1935483870967742,
#   'rougeL': 0.2424242424242424,
#   'rougeLsum': 0.2424242424242424},
#  {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0},
#  {'rouge1': 0.125, 'rouge2': 0.0, 'rougeL': 0.125, 'rougeLsum': 0.125},
#  {'rouge1': 0.6153846153846154,
#   'rouge2': 0.4166666666666667,
#   'rougeL': 0.6153846153846154,
#   'rougeLsum': 0.6153846153846154},
#  {'rouge1': 0.5384615384615384,
#   'rouge2': 0.16666666666666669,
#   'rougeL': 0.3846153846153846,
#   'rougeLsum': 0.3846153846153846},
#  {'rouge1': 0.16666666666666666,
#   'rouge2': 0.0,
#   'rougeL': 0.08333333333333333,
#   'rougeLsum': 0.08333333333333333},
#  {'rouge1': 0.07407407407407407,
#   'rouge2': 0.0,
#   'rougeL': 0.07407407407407407,
#   'rougeLsum': 0.07407407407407407},
#  {'rouge1': 0.19999999999999998,
#   'rouge2': 0.0,
#   'rougeL': 0.19999999999999998,
#   'rougeLsum': 0.19999999999999998},
#  {'rouge1': 0.5517241379310345,
#   'rouge2': 0.2962962962962963,
#   'rougeL': 0.3448275862068966,
#   'rougeLsum': 0.3448275862068966},
#  {'rouge1': 0.1818181818181818,
#   'rouge2': 0.04761904761904762,
#   'rougeL': 0.13636363636363635,
#   'rougeLsum': 0.13636363636363635},
#  {'rouge1': 0.06896551724137931,
#   'rouge2': 0.0,
#   'rougeL': 0.06896551724137931,
#   'rougeLsum': 0.06896551724137931},
#  {'rouge1': 0.18181818181818182,
#   'rouge2': 0.0,
#   'rougeL': 0.18181818181818182,
#   'rougeLsum': 0.18181818181818182},
#  {'rouge1': 0.08, 'rouge2': 0.0, 'rougeL': 0.08, 'rougeLsum': 0.08},
#  {'rouge1': 0.05714285714285714,
#   'rouge2': 0.0,
#   'rougeL': 0.05714285714285714,
#   'rougeLsum': 0.05714285714285714},
#  {'rouge1': 0.23999999999999996,
#   'rouge2': 0.08695652173913043,
#   'rougeL': 0.23999999999999996,
#   'rougeL': 0.06666666666666667,
#   'rougeLsum': 0.06666666666666667},
#  {'rouge1': 0.2222222222222222,
#   'rouge2': 0.05882352941176471,
#   'rougeL': 0.1111111111111111,
#   'rougeLsum': 0.1111111111111111}]

# %%
import statistics
rouge1 = []
rouge2 = []
rougeL = []
rougeLsum = []

# %%
for i in rouge_scores:
  rouge1.append(i['rouge1'])
  rouge2.append(i['rouge2'])
  rougeL.append(i['rougeL'])
  rougeLsum.append(i['rougeLsum'])

# %%
print("Variance of Rouge1: ", np.var(rouge1))
print("Variance of Rouge2: ", np.var(rouge2))
print("Variance of RougeL: ", np.var(rougeL))
print("Variance of RougeLSum: ", np.var(rougeLsum))

print("Median of Rouge1: ", statistics.median(rouge1))
print("Median of Rouge2: ", statistics.median(rouge2))
print("Median of RougeL: ", statistics.median(rougeL))
print("Median of RougeLSum: ", statistics.median(rougeLsum))

print("Average of Rouge1: ", sum(rouge1)/len(rouge1))
print("Average of Rouge2: ", sum(rouge2)/len(rouge2))
print("Average of RougeL: ", sum(rougeL)/len(rougeL))
print("Average of RougeLSum: ", sum(rougeLsum)/len(rougeLsum))

print("Max of Rouge1: ", max(rouge1))
print("Max of Rouge2: ", max(rouge2))
print("Max of RougeL: ", max(rougeL))
print("Max of RougeLSum: ", max(rougeLsum))

print("Min of Rouge1: ", min(rouge1))
print("Min of Rouge2: ", min(rouge2))
print("Min of RougeL: ", min(rougeL))
print("Min of RougeLSum: ", min(rougeLsum))

rougeL.index(max(rougeL))
print("\nMax")
print(headlines[rougeL.index(max(rougeL))])
print(generated_summary[rougeL.index(max(rougeL))])
print(rouge_scores[rougeL.index(max(rougeL))])
print("\nMin")
print(headlines[rougeL.index(min(rougeL))])
print(generated_summary[rougeL.index(min(rougeL))])
print(rouge_scores[rougeL.index(min(rougeL))])
# Out:
# Variance of Rouge1:  0.017460567104681395
# Variance of Rouge2:  0.006111782061118335
# Variance of RougeL:  0.010037224319846973
# Variance of RougeLSum:  0.010037224319846973
# Median of Rouge1:  0.13118279569892474
# Median of Rouge2:  0.0
# Median of RougeL:  0.10128205128205128
# Median of RougeLSum:  0.10128205128205128
# Average of Rouge1:  0.15715018842609657
# Average of Rouge2:  0.03720060232095358
# Average of RougeL:  0.12159704343095655
# Average of RougeLSum:  0.12159704343095655
# Max of Rouge1:  0.6153846153846154
# Max of Rouge2:  0.4166666666666667
# Max of RougeL:  0.6153846153846154
# Max of RougeLSum:  0.6153846153846154
# Min of Rouge1:  0.0
# Min of Rouge2:  0.0
# Min of RougeL:  0.0
# Min of RougeLSum:  0.0
#
# Max
# Trump seeks to revive Dakota Access, Keystone XL oil pipelines
# the president signed executive orders to revive the controversial Dakota Access and Keystone XL oil pipelines
# {'rouge1': 0.6153846153846154, 'rouge2': 0.4166666666666667, 'rougeL': 0.6153846153846154, 'rougeLsum': 0.6153846153846154}
#
# Min
# Looking back at New Year’s Eve in Times Square
# since 1907, there have been only two Januaries — 1942 and 1943
# {'rouge1': 0.0, 'rouge2': 0.0, 'rougeL': 0.0, 'rougeLsum': 0.0}
